# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/kaylar/Downloads/world-stats/world_country_stats.csv")
df
# Out:
#              country   region  land_area  fertility_rate  median_age
# 0        Afghanistan     Asia     652860             4.4        17.0
# 1            Albania   Europe      27400             1.4        38.0
# 2            Algeria   Africa    2381740             2.8        28.0
# 3     American Samoa  Oceania        200             2.2        29.0
# 4            Andorra   Europe        470             1.1        43.0
# ..               ...      ...        ...             ...         ...
# 229  Wallis & Futuna  Oceania        140             1.9        37.0
# 230   Western Sahara   Africa     266000             2.2        32.0
# 231            Yemen     Asia     527970             3.6        19.0
# 232           Zambia   Africa     743390             4.2        17.0
# 233         Zimbabwe   Africa     386850             3.4        18.0
#
# [234 rows x 5 columns]

# %%
df2 = pd.read_csv("/Users/kaylar/Downloads/world-stats/world_population_by_country_2023.csv")
df2
# Out:
#              country  population  yearly_change  net_change  density  \
# 0        Afghanistan    42239854           2.70     1111083       65
# 1            Albania     2832439          -0.35       -9882      103
# 2            Algeria    45606480           1.57      703255       19
# 3     American Samoa       43914          -0.81        -359      220
# 4            Andorra       80088           0.33         264      170
# ..               ...         ...            ...         ...      ...
# 229  Wallis & Futuna       11502          -0.60         -70       82
# 230   Western Sahara      587259           1.96       11273        2
# 231            Yemen    34449825           2.24      753211       65
# 232           Zambia    20569737           2.76      552062       28
# 233         Zimbabwe    16665409           2.11      344872       43
#
#      land_area  net_migrants  fertility_rate  median_age  population_urban  \
# ...

# %%
df.shape
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         234 non-null    object
#  1   region          234 non-null    object
#  2   land_area       234 non-null    int64
#  3   fertility_rate  233 non-null    float64
#  4   median_age      233 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 9.3+ KB

# %%
df2.shape
df2.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           234 non-null    object
#  1   population        234 non-null    int64
#  2   yearly_change     234 non-null    float64
#  3   net_change        234 non-null    int64
#  4   density           234 non-null    int64
#  5   land_area         234 non-null    int64
#  6   net_migrants      234 non-null    int64
#  7   fertility_rate    233 non-null    float64
#  8   median_age        233 non-null    float64
#  9   population_urban  216 non-null    float64
#  10  world_share       234 non-null    float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 20.2+ KB

# %%
df['fertility_rate'].mean()
# Out:
# 2.4141630901287554

# %%
df['median_age'].mean()
# Out:
# 31.30901287553648

# %%
top10= df2.nlargest(10, 'population')
top10
# Out:
#            country  population  yearly_change  net_change  density  land_area  \
# 95           India  1428627663           0.81    11454490      481    2973190
# 42           China  1425671352          -0.02     -215985      152    9388211
# 223  United States   339996563           0.50     1706706       37    9147420
# 96       Indonesia   277534122           0.74     2032783      153    1811570
# 157       Pakistan   240485658           1.98     4660796      312     770880
# 150        Nigeria   223804632           2.41     5263420      246     910770
# 27          Brazil   216422446           0.52     1108948       26    8358140
# 16      Bangladesh   172954319           1.03     1767947     1329     130170
# 170         Russia   144444359          -0.19     -268955        9   16376870
# 132         Mexico   128455567           0.75      951442       66    1943950
#
#      net_migrants  fertility_rate  median_age  population_urban  world_share
# ...

# %%
bottom10 = df2.nsmallest(10, 'population')
bottom10
# Out:
#                      country  population  yearly_change  net_change  density  \
# 90                  Holy See         518           1.57           8     1295
# 210                  Tokelau        1893           1.18          22      189
# 151                     Niue        1935           0.05           1        7
# 68             Faroe Islands        3791           0.29          11        0
# 138               Montserrat        4386          -0.09          -4       44
# 173             Saint Helena        5314          -1.12         -60       14
# 177  Saint Pierre & Miquelon        5840          -0.38         -22       25
# 172         Saint Barthelemy       10994           0.25          27      524
# 217                   Tuvalu       11396           0.74          84      380
# 229          Wallis & Futuna       11502          -0.60         -70       82
#
#      land_area  net_migrants  fertility_rate  median_age  population_urban  \
# ...

# %%
df2.describe()
# Out:
#          population  yearly_change    net_change       density     land_area  \
# count  2.340000e+02     234.000000  2.340000e+02    234.000000  2.340000e+02
# mean   3.437565e+07       0.965470  3.000230e+05    477.414530  5.559568e+05
# std    1.373861e+08       1.242413  1.001815e+06   2320.693692  1.691024e+06
# min    5.180000e+02      -7.450000 -2.957105e+06      0.000000  0.000000e+00
# 25%    4.696482e+05       0.222500  2.360000e+02     38.250000  2.650000e+03
# 50%    5.643895e+06       0.805000  2.860150e+04     96.500000  7.972000e+04
# 75%    2.324537e+07       1.685000  2.236855e+05    242.000000  4.070800e+05
# max    1.428628e+09       4.980000  1.145449e+07  24360.000000  1.637687e+07
#
#        net_migrants  fertility_rate  median_age  population_urban  world_share
# count  2.340000e+02      233.000000  233.000000        216.000000   234.000000
# mean   1.301282e+01        2.414163   31.309013         59.550926     0.427393
# ...

# %%
df.isnull().sum()
# Out:
# country           0
# region            0
# land_area         0
# fertility_rate    1
# median_age        1
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# country              0
# population           0
# yearly_change        0
# net_change           0
# density              0
# land_area            0
# net_migrants         0
# fertility_rate       1
# median_age           1
# population_urban    18
# world_share          0
# dtype: int64

# %%
df2.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
dflong = pd.read_csv("/Users/kaylar/Downloads/world-stats/world_population_by_year_1950_2023.csv")
dflong
# Out:
#              country     1950     1951     1952     1953      1954      1955  \
# 0        Afghanistan  7480461  7571537  7667533  7764546   7864285   7971931
# 1            Albania  1252582  1289168  1326948  1366744   1409005   1453730
# 2            Algeria  9019866  9271734  9521702  9771686  10011541  10242288
# 3     American Samoa    19032    19425    19561    19670     19758     19826
# 4            Andorra     6005     5827     5454     5308      5566      6116
# ..               ...      ...      ...      ...      ...       ...       ...
# 229  Wallis & Futuna     8535     8810     9169     9528      9693      9616
# 230   Western Sahara    12982    14267    15648    17165     18848     20690
# 231            Yemen  4712810  4782787  4855822  4931833   5010564   5091603
# 232           Zambia  2318448  2384836  2453511  2525024   2599541   2677209
# 233         Zimbabwe  2791326  2881713  2973713  3067899   3164517   3263625
#
# ...

# %%
joined_df = pd.merge(df, dflong, on="country", how='inner')
merged_df = pd.merge(joined_df, df2, on= 'country', how= 'inner')
non_match_val = merged_df[merged_df['population'] != merged_df['2023']]
non_match_val[['population', '2023']]
# Out:
#     population       2023
# 27   216422446  223804632
# 54     5910913  102262808
# 55     1136455    5910913
# 56       73040    1136455
# 57    11332972      73040
# 58   102262808   11332972
# 67       53270       3791
# 68        3791      53270

# %%
merged_df
# Out:
#              country   region  land_area_x  fertility_rate_x  median_age_x  \
# 0        Afghanistan     Asia       652860               4.4          17.0
# 1            Albania   Europe        27400               1.4          38.0
# 2            Algeria   Africa      2381740               2.8          28.0
# 3     American Samoa  Oceania          200               2.2          29.0
# 4            Andorra   Europe          470               1.1          43.0
# ..               ...      ...          ...               ...           ...
# 229  Wallis & Futuna  Oceania          140               1.9          37.0
# 230   Western Sahara   Africa       266000               2.2          32.0
# 231            Yemen     Asia       527970               3.6          19.0
# 232           Zambia   Africa       743390               4.2          17.0
# 233         Zimbabwe   Africa       386850               3.4          18.0
#
# ...

# %%
merged_df.replace(to_replace ="NaN", value = 0)
# Out:
#              country   region  land_area_x  fertility_rate_x  median_age_x  \
# 0        Afghanistan     Asia       652860               4.4          17.0
# 1            Albania   Europe        27400               1.4          38.0
# 2            Algeria   Africa      2381740               2.8          28.0
# 3     American Samoa  Oceania          200               2.2          29.0
# 4            Andorra   Europe          470               1.1          43.0
# ..               ...      ...          ...               ...           ...
# 229  Wallis & Futuna  Oceania          140               1.9          37.0
# 230   Western Sahara   Africa       266000               2.2          32.0
# 231            Yemen     Asia       527970               3.6          19.0
# 232           Zambia   Africa       743390               4.2          17.0
# 233         Zimbabwe   Africa       386850               3.4          18.0
#
# ...

# %%
mergedTop10 = merged_df.nlargest(10, 'population')
mergedTop10 # multiple asian countries were in the top 10 countries in population
# Out:
#            country         region  land_area_x  fertility_rate_x  \
# 95           India           Asia      2973190               2.0
# 42           China           Asia      9388211               1.2
# 223  United States  North America      9147420               1.7
# 96       Indonesia           Asia      1811570               2.1
# 157       Pakistan           Asia       770880               3.3
# 150        Nigeria         Africa       910770               5.1
# 27          Brazil  Latin America      8358140               1.6
# 16      Bangladesh           Asia       130170               1.9
# 170         Russia         Europe     16376870               1.5
# 132         Mexico  Latin America      1943950               1.8
#
#      median_age_x       1950       1951       1952       1953       1954  ...  \
# 95           28.0  357021100  364922360  372997188  381227705  389731406  ...
# 42           39.0  543979233  553613988  564954522  577378682  589936004  ...
# ...

# %%
sns.barplot(x='country', y='population', data=mergedTop10)
plt.xticks(rotation=90)
plt.show() # India and China have a significantly larger population than the other 8 largest countries

# %%
mergedBottom10 = merged_df.nsmallest(10, 'population')
mergedBottom10 # the continent that has the most amount of countries that have the least populations is oceania
# Out:
#                      country         region  land_area_x  fertility_rate_x  \
# 90                  Holy See         Europe            0               NaN
# 210                  Tokelau        Oceania           10               2.6
# 151                     Niue        Oceania          260               2.4
# 68             Faroe Islands         Europe         1396               2.7
# 138               Montserrat  Latin America          100               1.6
# 173             Saint Helena         Africa          390               1.6
# 177  Saint Pierre & Miquelon  North America          230               1.6
# 172         Saint Barthelemy  North America           21               1.0
# 217                   Tuvalu        Oceania           30               3.1
# 229          Wallis & Futuna        Oceania          140               1.9
#
#      median_age_x   1950   1951   1952   1953   1954  ...  population  \
# 90            NaN    880    886    892    898    905  ...         518
# ...

# %%
sns.barplot(x='country', y='population', data=mergedBottom10)
# Out:
# <Axes: xlabel='country', ylabel='population'>

# %%
mergedTop10['population'].mean()
# Out:
# 459839668.1

# %%
mergedTop10['yearly_change'].mean() # top 10 have a greater amount of change than bottom 10
# Out:
# 0.8530000000000001

# %%
mergedBottom10['yearly_change'].mean()
# Out:
# 0.18899999999999992

# %%
mergedBottom10['population'].mean()
# Out:
# 5756.9

# %%
sns.barplot(x='country', y='population', data=mergedBottom10)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='country', y='land_area_x', data=mergedBottom10)
plt.xticks(rotation=90)
plt.show()
# the bottom countries in population usually have smaller land areas, with the exception of Faroe Islands

# %%
sns.barplot(x='country', y='fertility_rate_x', data=mergedBottom10)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='country', y='fertility_rate_x', data=mergedTop10)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='country', y='yearly_change', data=mergedTop10)
plt.xticks(rotation=90)
plt.show() # Top 10 countries tend to have a more significant yearly change

# %%
sns.barplot(x='country', y='yearly_change', data=mergedBottom10)
plt.xticks(rotation=90)
plt.show() # Bottom 10 tend to have a decrease in yearly change

# %%
bottom10Years = mergedBottom10[['country','1950', '2023']]
bottom10Years
# Out:
#                      country   1950   2023
# 90                  Holy See    880    518
# 210                  Tokelau   1599   1893
# 151                     Niue   4485   1935
# 68             Faroe Islands  31655  53270
# 138               Montserrat  12989   4386
# 173             Saint Helena   5224   5314
# 177  Saint Pierre & Miquelon   4473   5840
# 172         Saint Barthelemy   2007  10994
# 217                   Tuvalu   4732  11396
# 229          Wallis & Futuna   8535  11502

# %%
bottom10Years.plot.bar(x='country');
plt.show()

# %%
top10Years = mergedTop10[['country','1950','2023']]
top10Years
# Out:
#            country       1950        2023
# 95           India  357021100  1428627663
# 42           China  543979233  1425671352
# 223  United States  148281550   339996563
# 96       Indonesia   69567619   277534122
# 157       Pakistan   37696264   240485658
# 150        Nigeria   37189369   223804632
# 27          Brazil   37189369   223804632
# 16      Bangladesh   39728535   172954319
# 170         Russia  102580107   144444359
# 132         Mexico   27600133   128455567

# %%
top10Years.plot.bar(x='country');
plt.show() # india and china experienced the greatest amount of growth
# all countries populations nearly doubled in size besides russia

# %%
top10Decade = mergedTop10[['country','1950', '1963', '1973', '1983', '1993', '2003', '2013','2023']]
top10Decade
# Out:
#            country       1950       1963       1973        1983        1993  \
# 95           India  357021100  477933619  596107483   745826546   926351297
# 42           China  543979233  683903557  881652080  1029226907  1195855558
# 223  United States  148281550  184649873  207314764   230389964   258779753
# 96       Indonesia   69567619   95962527  124709058   158790611   191737287
# 157       Pakistan   37696264   49325050   64285624    91080372   125546615
# 150        Nigeria   37189369   47822569   59605446    79351586   102775465
# 27          Brazil   37189369   47822569   59605446    79351586   102775465
# 16      Bangladesh   39728535   55094115   71144818    91045478   113418757
# 170         Russia  102580107  124227725  132191634   140854123   148897270
# 132         Mexico   27600133   39982118   55228203    72080310    86648447
#
#            2003        2013        2023
# 95   1117415123  1291132063  1428627663
# 42   1288873367  1376100308  1425671352
# ...

# %%
top10Decade.plot.bar(x='country');
plt.show() # pakistan and nigeria had exponential growth
# mostly consistently growing throughout the decades

# %%
bottom10Decade = mergedBottom10[['country','1950', '1963', '1973', '1983', '1993', '2003', '2013','2023']]
bottom10Decade
# Out:
#                      country   1950   1963   1973   1983   1993   2003   2013  \
# 90                  Holy See    880    917    746    727    683    638    574
# 210                  Tokelau   1599   1879   1625   1663   1645   1585   1502
# 151                     Niue   4485   5090   4719   3224   2416   1928   1825
# 68             Faroe Islands  31655  35385  39746  44669  45096  47392  48418
# 138               Montserrat  12989  11862  11476  11232   9547   4627   5010
# 173             Saint Helena   5224   5439   6002   6574   6463   5747   5422
# 177  Saint Pierre & Miquelon   4473   4996   5827   6129   6396   6202   6005
# 172         Saint Barthelemy   2007   2275   2484   3483   5762   7655   9338
# 217                   Tuvalu   4732   5503   5934   8099   9517   9668  10918
# 229          Wallis & Futuna   8535   8621   9610  12511  13900  15031  12464
#
#       2023
# 90     518
# 210   1893
# 151   1935
# 68   53270
# 138   4386
# 173   5314
# 177   5840
# ...

# %%
bottom10Decade.plot.bar(x='country');
plt.show() # growth is not consistent in lower countries
